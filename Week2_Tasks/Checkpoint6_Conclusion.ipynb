# %% [markdown]
# # Checkpoint 6: Final conclusion
# A written conclusion that links the statistical result to a business decision

# %% [markdown]
# ## 1. Recap of what was tested and found

# %%
results_summary = {
    "Test": ["Gearbox vs. price (t-test)", "Brand vs. price (ANOVA)", "Gearbox vs. drivetrain (chi-square)"],
    "p-value": ["~0", "~0", "~0"],
    "Effect size": ["Cohen's d = 0.66 (medium-large)", "eta² = 0.082 (small)", "Cramer's V = 0.218 (weak-moderate)"],
    "Key number": ["Auto cars cost ~19,456 AZN more on average", "Brand explains ~8% of price variation", "Gearbox and drivetrain are linked, but weakly"]
}
import pandas as pd
pd.DataFrame(results_summary)
# Out:
#                                   Test p-value  \
# 0           Gearbox vs. price (t-test)      ~0
# 1              Brand vs. price (ANOVA)      ~0
# 2  Gearbox vs. drivetrain (chi-square)      ~0
#
#                           Effect size  \
# 0     Cohen's d = 0.66 (medium-large)
# 1                eta² = 0.082 (small)
# 2  Cramer's V = 0.218 (weak-moderate)
#
#                                       Key number
# 0     Auto cars cost ~19,456 AZN more on average
# 1          Brand explains ~8% of price variation
# 2  Gearbox and drivetrain are linked, but weakly

# %% [markdown]
# ## 2. Written conclusion

# %% [markdown]
# If I were advising someone selling cars on Turbo.az, here's what I'd tell them:
#
#
# The strongest price driver I found is gearbox type. Automatic cars sell for about 19,456 AZN more than manual cars on average (95% CI: 19,227–19,684 AZN). This isn't a tiny statistical detail. Cohen's d = 0.66 means it's a real, noticeable gap in practice.
#
# Business decision:
#
# If someone is deciding whether to list a car as automatic or manual, or whether it's worth upgrading the gearbox before selling, this data says automatic transmission adds real value in this market.Brand also matters, but much less in practice, it only explains about 8% of the price differences. So yes, a Mercedes tends to cost more than a LADA, but brand alone is a weak reason to price something higher. Year, mileage, and condition likely explain most of the remaining price difference, nt brand by itself.The link between gearbox and drivetrain is more of a side pattern than something to act on automatic cars tend to come with certain drivetrains more often, but the connection is too weak to base a pricing or inventory decision on.
#
# If I had to focus on one thing, it's gearbox type, it has the biggest and most reliable effect on price out of everything I tested.
